# %%
import acousticFeature
import linguisticFeature
import glob
import pandas as pd
# Out:
# /home2/ducvu/miniconda3/envs/dementia-speech/lib/python3.12/site-packages/ideadensity/tagger.py:5: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources

# %% [markdown]
# # LINGUISTIC FEATURES

# %%
BASE_PATH = "/mnt/data_lab513/ducvu/ADReSSo/ADReSSo-feature-extration"

# %%
TRANSCRIPT_PATH = f"{BASE_PATH}/output/transcripts"
print(TRANSCRIPT_PATH)
# Out:
# /mnt/data_lab513/ducvu/ADReSSo/ADReSSo-feature-extration/output/transcripts

# %%
first_transcription = glob.glob(TRANSCRIPT_PATH + "/*.csv")[0]
print(first_transcription)
# Out:
# /mnt/data_lab513/ducvu/ADReSSo/ADReSSo-feature-extration/output/transcripts/adresso_transcripts_whisper-large-v3.csv

# %%
df = pd.read_csv(first_transcription)
print(df)
# Out:
#      files_id diagnosis                                         transcript
# 0    adrso024        ad  There's a cookie jar and the lid is off the co...
# 1    adrso025        ad  Tell me everything that's going on. Well, the ...
# 2    adrso027        ad  There's a little girl and a little boy standin...
# 3    adrso028        ad  How she would find her, and the mother's wishe...
# 4    adrso031        ad  What do you see going on? Well, the boy's on a...
# ..        ...       ...                                                ...
# 161  adrso309        cn  Bring in that picture. Tell me everything that...
# 162  adrso310        cn  Okay, I just want you to tell me what you see ...
# 163  adrso312        cn  What do you see going on in that picture? Oh, ...
# 164  adrso315        cn  Just the action. The girl is reaching for a co...
# 165  adrso316        cn  I'd like you to tell me everything that you se...
#
# [166 rows x 3 columns]

# %%
test_first_transcription = df["transcript"][50]
print(test_first_transcription)
# Out:
# Okay. Can you tell me now? Well, this one is in the cookie jar, and this is, she tried to climb the, oh, no, no, this boy. I think this is the same one, huh? Tried to get in the cookie jar, and she's watching. And over here must be the mother. I don't know what the heck they're doing here. Can you tell me something else that's going on over here? What's going on? Mm-hmm. The stool, she was climbing, and the stool tipped over. Okay. How about over here? Is there something else going on over here? And she was doing the dishes, I think. Okay. She spilled something. Okay, that's fine.

# %%
cttr, brunet, honore, std_entropy, pidensity = linguisticFeature.lexical_richness(test_first_transcription, lang="en")
# Out:
# /home2/ducvu/miniconda3/envs/dementia-speech/lib/python3.12/site-packages/spacy/util.py:969: UserWarning: [W095] Model 'en_core_web_sm' (3.7.1) was trained with spaCy v3.7.2 and may not be 100% compatible with the current version (3.8.11). If you see errors or degraded performance, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)

# %%
print(f"corrected TTR: {cttr}, burnet: {brunet}, honore: {honore}, std_entropy: {std_entropy}, pidensity: {pidensity}")
# Out:
# corrected TTR: 7.58, burnet: 8.75, honore: None, std_entropy: 1.44271, pidensity: 0.28926

# %% [markdown]
# # ACOUSTIC FEATURES
